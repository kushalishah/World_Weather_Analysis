# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
from datetime import datetime
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=664a1f38424f0b056080ef1b2a40e9ff

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    time.sleep(0.1)

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | skoppum
# Processing Record 2 of Set 1 | guerrero negro
# Processing Record 3 of Set 1 | gaoua
# Processing Record 4 of Set 1 | vostok
# Processing Record 5 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | benguela
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | chapaevsk
# Processing Record 11 of Set 1 | vardo
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | nantucket
# Processing Record 14 of Set 1 | yaring
# Processing Record 15 of Set 1 | port macquarie
# Processing Record 16 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 17 of Set 1 | karasburg
# Processing Record 18 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 1 | bilibino
# Processing Record 20 of Set 1 | namatanai
# Processing Record 21 of Set 1 | sitka
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | sundsvall
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | eatonton
# Processing Record 26 of Set 1 | khovu-aksy
# Processing Record 27 of Set 1 | lagoa
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | lompoc
# Processing Record 32 of Set 1 | srednekolymsk
# Processing Record 33 of Set 1 | dongning
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | tuatapere
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | grand-santi
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | uglegorsk
# Processing Record 46 of Set 1 | peleduy
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | ponta delgada
# Processing Record 49 of Set 1 | baykit
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | caravelas
# Processing Record 3 of Set 2 | johnston
# Processing Record 4 of Set 2 | huarmey
# Processing Record 5 of Set 2 | carthage
# Processing Record 6 of Set 2 | fortuna
# Processing Record 7 of Set 2 | lorengau
# Processing Record 8 of Set 2 | aykhal
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | avera
# Processing Record 12 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 2 | egham
# Processing Record 14 of Set 2 | novooleksiyivka
# Processing Record 15 of Set 2 | nome
# Processing Record 16 of Set 2 | yaan
# Processing Record 17 of Set 2 | rikitea
# Processing Record 18 of Set 2 | na klang
# Processing Record 19 of Set 2 | sorland
# Processing Record 20 of Set 2 | kungurtug
# Processing Record 21 of Set 2 | grindavik
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | aklavik
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | broken hill
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | coulihaut
# City not found. Skipping...
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | hualmay
# Processing Record 30 of Set 2 | banda aceh
# Processing Record 31 of Set 2 | marion
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | palmer
# Processing Record 34 of Set 2 | vila velha
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | saldanha
# Processing Record 39 of Set 2 | port loko
# Processing Record 40 of Set 2 | lata
# Processing Record 41 of Set 2 | maracanau
# Processing Record 42 of Set 2 | svetlogorsk
# Processing Record 43 of Set 2 | kununurra
# Processing Record 44 of Set 2 | rossland
# Processing Record 45 of Set 2 | guaruja
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | ileza
# Processing Record 49 of Set 2 | ushuaia
# Processing Record 50 of Set 2 | imeni poliny osipenko
# Processing Record 1 of Set 3 | ocho rios
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | santa isabel
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | virginia beach
# Processing Record 6 of Set 3 | kirakira
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | westport
# Processing Record 9 of Set 3 | mandalgovi
# Processing Record 10 of Set 3 | iberia
# Processing Record 11 of Set 3 | vestmannaeyjar
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | oneonta
# Processing Record 15 of Set 3 | vilcun
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | akyab
# Processing Record 18 of Set 3 | fort nelson
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | kupang
# Processing Record 22 of Set 3 | ust-tsilma
# Processing Record 23 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 24 of Set 3 | atambua
# Processing Record 25 of Set 3 | samarai
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | goundam
# Processing Record 28 of Set 3 | puerto carreno
# Processing Record 29 of Set 3 | governador valadares
# Processing Record 30 of Set 3 | litovko
# Processing Record 31 of Set 3 | sechura
# Processing Record 32 of Set 3 | calama
# Processing Record 33 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 3 | butaritari
# Processing Record 35 of Set 3 | chara
# Processing Record 36 of Set 3 | arman
# Processing Record 37 of Set 3 | puerto ayacucho
# Processing Record 38 of Set 3 | san patricio
# Processing Record 39 of Set 3 | formosa
# Processing Record 40 of Set 3 | chuy
# Processing Record 41 of Set 3 | airai
# Processing Record 42 of Set 3 | yellowknife
# Processing Record 43 of Set 3 | bartica
# Processing Record 44 of Set 3 | souillac
# Processing Record 45 of Set 3 | general roca
# Processing Record 46 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 3 | mbandaka
# Processing Record 48 of Set 3 | constitucion
# Processing Record 49 of Set 3 | ahipara
# Processing Record 50 of Set 3 | balkhash
# Processing Record 1 of Set 4 | ouango
# Processing Record 2 of Set 4 | otane
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | banmankhi
# Processing Record 5 of Set 4 | beringovskiy
# Processing Record 6 of Set 4 | portland
# Processing Record 7 of Set 4 | arlit
# Processing Record 8 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 4 | lazaro cardenas
# Processing Record 10 of Set 4 | hornepayne
# Processing Record 11 of Set 4 | kahului
# Processing Record 12 of Set 4 | fonseca
# Processing Record 13 of Set 4 | kabo
# Processing Record 14 of Set 4 | ambulu
# Processing Record 15 of Set 4 | leningradskiy
# Processing Record 16 of Set 4 | mount isa
# Processing Record 17 of Set 4 | conroe
# Processing Record 18 of Set 4 | visnes
# Processing Record 19 of Set 4 | togur
# Processing Record 20 of Set 4 | necochea
# Processing Record 21 of Set 4 | sweetwater
# Processing Record 22 of Set 4 | vangaindrano
# Processing Record 23 of Set 4 | amlagora
# Processing Record 24 of Set 4 | prachuap khiri khan
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | bulawayo
# Processing Record 27 of Set 4 | basoko
# Processing Record 28 of Set 4 | krasnoselkup
# Processing Record 29 of Set 4 | atar
# Processing Record 30 of Set 4 | merauke
# Processing Record 31 of Set 4 | ambovombe
# Processing Record 32 of Set 4 | hirara
# Processing Record 33 of Set 4 | chokurdakh
# Processing Record 34 of Set 4 | havoysund
# Processing Record 35 of Set 4 | vilhena
# Processing Record 36 of Set 4 | ormara
# Processing Record 37 of Set 4 | puro
# Processing Record 38 of Set 4 | tocopilla
# Processing Record 39 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 4 | ous
# Processing Record 41 of Set 4 | tongchuan
# Processing Record 42 of Set 4 | xiongzhou
# Processing Record 43 of Set 4 | choya
# Processing Record 44 of Set 4 | ravar
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | tazovskiy
# Processing Record 47 of Set 4 | saint-pierre
# Processing Record 48 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 4 | kavieng
# Processing Record 50 of Set 4 | omboue
# Processing Record 1 of Set 5 | dondo
# Processing Record 2 of Set 5 | vanimo
# Processing Record 3 of Set 5 | san quintin
# Processing Record 4 of Set 5 | nsanje
# Processing Record 5 of Set 5 | bathsheba
# Processing Record 6 of Set 5 | castro
# Processing Record 7 of Set 5 | san marcos
# Processing Record 8 of Set 5 | talaya
# Processing Record 9 of Set 5 | naze
# Processing Record 10 of Set 5 | port-gentil
# Processing Record 11 of Set 5 | bahia de caraquez
# Processing Record 12 of Set 5 | bethel
# Processing Record 13 of Set 5 | iskateley
# Processing Record 14 of Set 5 | san juan
# Processing Record 15 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 5 | zhezkazgan
# Processing Record 17 of Set 5 | ulladulla
# Processing Record 18 of Set 5 | hithadhoo
# Processing Record 19 of Set 5 | imbituba
# Processing Record 20 of Set 5 | gashua
# Processing Record 21 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 5 | newala
# Processing Record 23 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 24 of Set 5 | quelimane
# Processing Record 25 of Set 5 | katsuura
# Processing Record 26 of Set 5 | shahr-e kord
# Processing Record 27 of Set 5 | saint george
# Processing Record 28 of Set 5 | guayape
# Processing Record 29 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 5 | colares
# Processing Record 31 of Set 5 | bonavista
# Processing Record 32 of Set 5 | lumphat
# Processing Record 33 of Set 5 | lasa
# Processing Record 34 of Set 5 | jasper
# Processing Record 35 of Set 5 | alexandria
# Processing Record 36 of Set 5 | dandong
# Processing Record 37 of Set 5 | port elizabeth
# Processing Record 38 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 5 | dunedin
# Processing Record 40 of Set 5 | kolkwitz
# Processing Record 41 of Set 5 | porirua
# Processing Record 42 of Set 5 | inveraray
# City not found. Skipping...
# Processing Record 43 of Set 5 | pindwara
# Processing Record 44 of Set 5 | fairbanks
# Processing Record 45 of Set 5 | walla walla
# Processing Record 46 of Set 5 | cape town
# Processing Record 47 of Set 5 | kyshtovka
# Processing Record 48 of Set 5 | avarua
# Processing Record 49 of Set 5 | ponta do sol
# Processing Record 50 of Set 5 | nikolayevsk-na-amure
# Processing Record 1 of Set 6 | codrington
# Processing Record 2 of Set 6 | faanui
# Processing Record 3 of Set 6 | rundu
# Processing Record 4 of Set 6 | jalu
# Processing Record 5 of Set 6 | kaitangata
# Processing Record 6 of Set 6 | touros
# Processing Record 7 of Set 6 | tessalit
# Processing Record 8 of Set 6 | tiksi
# Processing Record 9 of Set 6 | road town
# Processing Record 10 of Set 6 | karratha
# Processing Record 11 of Set 6 | dingle
# Processing Record 12 of Set 6 | cidreira
# Processing Record 13 of Set 6 | alice springs
# Processing Record 14 of Set 6 | konotop
# Processing Record 15 of Set 6 | cienfuegos
# Processing Record 16 of Set 6 | monte patria
# Processing Record 17 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 6 | saint-francois
# Processing Record 19 of Set 6 | lloydminster
# Processing Record 20 of Set 6 | pacific grove
# Processing Record 21 of Set 6 | paz de ariporo
# City not found. Skipping...
# Processing Record 22 of Set 6 | madang
# Processing Record 23 of Set 6 | broome
# Processing Record 24 of Set 6 | cabo san lucas
# Processing Record 25 of Set 6 | jinxiang
# Processing Record 26 of Set 6 | makakilo city
# Processing Record 27 of Set 6 | flinders
# Processing Record 28 of Set 6 | ketchikan
# Processing Record 29 of Set 6 | paranavai
# Processing Record 30 of Set 6 | muyezerskiy
# Processing Record 31 of Set 6 | zverinogolovskoye
# Processing Record 32 of Set 6 | victoria falls
# Processing Record 33 of Set 6 | lac du bonnet
# Processing Record 34 of Set 6 | torbay
# Processing Record 35 of Set 6 | zaraza
# Processing Record 36 of Set 6 | sola
# Processing Record 37 of Set 6 | tasiilaq
# Processing Record 38 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 6 | yining
# Processing Record 40 of Set 6 | hasaki
# Processing Record 41 of Set 6 | isangel
# Processing Record 42 of Set 6 | enderby
# Processing Record 43 of Set 6 | estelle
# Processing Record 44 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 45 of Set 6 | yulara
# Processing Record 46 of Set 6 | egvekinot
# Processing Record 47 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 48 of Set 6 | sulangan
# Processing Record 49 of Set 6 | umea
# Processing Record 50 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 7 | korhogo
# Processing Record 2 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 7 | fredericksburg
# Processing Record 4 of Set 7 | hambantota
# Processing Record 5 of Set 7 | phek
# Processing Record 6 of Set 7 | kautokeino
# Processing Record 7 of Set 7 | laguna
# Processing Record 8 of Set 7 | luganville
# Processing Record 9 of Set 7 | dikson
# Processing Record 10 of Set 7 | poronaysk
# Processing Record 11 of Set 7 | khatanga
# Processing Record 12 of Set 7 | komsomolskiy
# Processing Record 13 of Set 7 | mackenzie
# Processing Record 14 of Set 7 | lavrentiya
# Processing Record 15 of Set 7 | tonosho
# Processing Record 16 of Set 7 | mungwi
# Processing Record 17 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 18 of Set 7 | bengkulu
# Processing Record 19 of Set 7 | kutum
# Processing Record 20 of Set 7 | dakar
# Processing Record 21 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 7 | redlands
# Processing Record 23 of Set 7 | mugla
# Processing Record 24 of Set 7 | haines junction
# Processing Record 25 of Set 7 | san ramon
# Processing Record 26 of Set 7 | kiama
# Processing Record 27 of Set 7 | mombetsu
# Processing Record 28 of Set 7 | baghdad
# Processing Record 29 of Set 7 | athabasca
# Processing Record 30 of Set 7 | hamilton
# Processing Record 31 of Set 7 | sioux lookout
# Processing Record 32 of Set 7 | cape canaveral
# Processing Record 33 of Set 7 | port lincoln
# Processing Record 34 of Set 7 | ganzhou
# Processing Record 35 of Set 7 | vallenar
# Processing Record 36 of Set 7 | weligama
# Processing Record 37 of Set 7 | barcelos
# Processing Record 38 of Set 7 | itupiranga
# Processing Record 39 of Set 7 | te anau
# Processing Record 40 of Set 7 | ostrovnoy
# Processing Record 41 of Set 7 | abong mbang
# Processing Record 42 of Set 7 | ancud
# Processing Record 43 of Set 7 | the valley
# Processing Record 44 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 45 of Set 7 | praia da vitoria
# Processing Record 46 of Set 7 | mahibadhoo
# Processing Record 47 of Set 7 | hay river
# Processing Record 48 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 49 of Set 7 | ryazan
# Processing Record 50 of Set 7 | acajutla
# Processing Record 1 of Set 8 | rantepao
# Processing Record 2 of Set 8 | nuevo casas grandes
# Processing Record 3 of Set 8 | san antonio
# Processing Record 4 of Set 8 | hervey bay
# Processing Record 5 of Set 8 | padang
# Processing Record 6 of Set 8 | iqaluit
# Processing Record 7 of Set 8 | khash
# Processing Record 8 of Set 8 | arona
# Processing Record 9 of Set 8 | maarianhamina
# Processing Record 10 of Set 8 | xichang
# Processing Record 11 of Set 8 | sycow
# Processing Record 12 of Set 8 | campoverde
# Processing Record 13 of Set 8 | carnarvon
# Processing Record 14 of Set 8 | oranjemund
# Processing Record 15 of Set 8 | santiago del estero
# Processing Record 16 of Set 8 | havelock
# Processing Record 17 of Set 8 | wanning
# Processing Record 18 of Set 8 | alofi
# Processing Record 19 of Set 8 | moose factory
# Processing Record 20 of Set 8 | poum
# Processing Record 21 of Set 8 | portree
# Processing Record 22 of Set 8 | payo
# Processing Record 23 of Set 8 | zhigansk
# Processing Record 24 of Set 8 | poitiers
# Processing Record 25 of Set 8 | bardiyah
# Processing Record 26 of Set 8 | tual
# Processing Record 27 of Set 8 | muscle shoals
# Processing Record 28 of Set 8 | coquimbo
# Processing Record 29 of Set 8 | geraldton
# Processing Record 30 of Set 8 | faya
# Processing Record 31 of Set 8 | itaituba
# Processing Record 32 of Set 8 | micoud
# Processing Record 33 of Set 8 | nishihara
# Processing Record 34 of Set 8 | henties bay
# Processing Record 35 of Set 8 | mahon
# Processing Record 36 of Set 8 | tautira
# Processing Record 37 of Set 8 | bodinayakkanur
# Processing Record 38 of Set 8 | erenhot
# Processing Record 39 of Set 8 | longyearbyen
# Processing Record 40 of Set 8 | peniche
# Processing Record 41 of Set 8 | margate
# Processing Record 42 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 43 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 8 | kavaratti
# Processing Record 45 of Set 8 | tromso
# Processing Record 46 of Set 8 | korla
# Processing Record 47 of Set 8 | mezen
# Processing Record 48 of Set 8 | orsha
# Processing Record 49 of Set 8 | severo-kurilsk
# Processing Record 50 of Set 8 | carballo
# Processing Record 1 of Set 9 | kysyl-syr
# Processing Record 2 of Set 9 | sawtell
# Processing Record 3 of Set 9 | klichka
# Processing Record 4 of Set 9 | linhares
# Processing Record 5 of Set 9 | sao felix do xingu
# Processing Record 6 of Set 9 | duncan
# Processing Record 7 of Set 9 | vitim
# Processing Record 8 of Set 9 | freeport
# Processing Record 9 of Set 9 | oktyabrskiy
# Processing Record 10 of Set 9 | ilulissat
# Processing Record 11 of Set 9 | seoul
# Processing Record 12 of Set 9 | price
# Processing Record 13 of Set 9 | sheopur
# Processing Record 14 of Set 9 | ilhabela
# Processing Record 15 of Set 9 | beipiao
# Processing Record 16 of Set 9 | cabudare
# Processing Record 17 of Set 9 | bahia blanca
# Processing Record 18 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 19 of Set 9 | moroni
# Processing Record 20 of Set 9 | san cristobal
# Processing Record 21 of Set 9 | hingoli
# Processing Record 22 of Set 9 | hofn
# Processing Record 23 of Set 9 | simbahan
# Processing Record 24 of Set 9 | mosquera
# Processing Record 25 of Set 9 | puteyets
# Processing Record 26 of Set 9 | kedrovoye
# Processing Record 27 of Set 9 | yerbogachen
# Processing Record 28 of Set 9 | ellon
# Processing Record 29 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 9 | manjacaze
# Processing Record 31 of Set 9 | bama
# Processing Record 32 of Set 9 | kelo
# Processing Record 33 of Set 9 | itarema
# Processing Record 34 of Set 9 | manakara
# Processing Record 35 of Set 9 | aldan
# Processing Record 36 of Set 9 | bukan
# Processing Record 37 of Set 9 | nefteyugansk
# Processing Record 38 of Set 9 | camacha
# Processing Record 39 of Set 9 | dingli
# Processing Record 40 of Set 9 | norman wells
# Processing Record 41 of Set 9 | mazatlan
# Processing Record 42 of Set 9 | rio grande
# Processing Record 43 of Set 9 | turkistan
# Processing Record 44 of Set 9 | nizwa
# Processing Record 45 of Set 9 | ambilobe
# Processing Record 46 of Set 9 | tete
# Processing Record 47 of Set 9 | san miguel de cauri
# Processing Record 48 of Set 9 | unity
# Processing Record 49 of Set 9 | batagay-alyta
# Processing Record 50 of Set 9 | olafsvik
# Processing Record 1 of Set 10 | palmira
# Processing Record 2 of Set 10 | cairns
# Processing Record 3 of Set 10 | great falls
# Processing Record 4 of Set 10 | tura
# Processing Record 5 of Set 10 | san felipe
# Processing Record 6 of Set 10 | adelanto
# Processing Record 7 of Set 10 | byron bay
# Processing Record 8 of Set 10 | hobyo
# Processing Record 9 of Set 10 | ahuimanu
# Processing Record 10 of Set 10 | maceio
# Processing Record 11 of Set 10 | luis correia
# Processing Record 12 of Set 10 | ende
# Processing Record 13 of Set 10 | klaksvik
# Processing Record 14 of Set 10 | puerto leguizamo
# Processing Record 15 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 16 of Set 10 | gao
# Processing Record 17 of Set 10 | qeshm
# Processing Record 18 of Set 10 | staryy nadym
# Processing Record 19 of Set 10 | genhe
# Processing Record 20 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 10 | toungoo
# City not found. Skipping...
# Processing Record 22 of Set 10 | acapulco
# Processing Record 23 of Set 10 | guilin
# Processing Record 24 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 10 | staicele
# Processing Record 26 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 10 | vidim
# Processing Record 28 of Set 10 | ritterhude
# Processing Record 29 of Set 10 | paamiut
# Processing Record 30 of Set 10 | lakhtar
# Processing Record 31 of Set 10 | grande prairie
# Processing Record 32 of Set 10 | vao
# Processing Record 33 of Set 10 | taoudenni
# Processing Record 34 of Set 10 | valparaiso
# Processing Record 35 of Set 10 | beni
# Processing Record 36 of Set 10 | forestville
# Processing Record 37 of Set 10 | port hedland
# Processing Record 38 of Set 10 | praia
# Processing Record 39 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 10 | bonthe
# Processing Record 41 of Set 10 | la ronge
# Processing Record 42 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 43 of Set 10 | vredendal
# Processing Record 44 of Set 10 | nelson bay
# Processing Record 45 of Set 10 | boguchany
# Processing Record 46 of Set 10 | charters towers
# Processing Record 47 of Set 10 | san vicente
# Processing Record 48 of Set 10 | quatre cocos
# Processing Record 49 of Set 10 | guarapari
# Processing Record 50 of Set 10 | saint combs
# City not found. Skipping...
# Processing Record 1 of Set 11 | nago
# Processing Record 2 of Set 11 | severnyy-kospashskiy
# Processing Record 3 of Set 11 | mazamari
# Processing Record 4 of Set 11 | teguise
# Processing Record 5 of Set 11 | salinopolis
# Processing Record 6 of Set 11 | belmonte
# Processing Record 7 of Set 11 | odesskoye
# Processing Record 8 of Set 11 | yumen
# Processing Record 9 of Set 11 | ishinomaki
# Processing Record 10 of Set 11 | saint anthony
# Processing Record 11 of Set 11 | banjar
# Processing Record 12 of Set 11 | sandwick
# Processing Record 13 of Set 11 | karasjok
# Processing Record 14 of Set 11 | victor harbor
# Processing Record 15 of Set 11 | cayenne
# Processing Record 16 of Set 11 | comodoro rivadavia
# Processing Record 17 of Set 11 | talnakh
# Processing Record 18 of Set 11 | catamarca
# Processing Record 19 of Set 11 | kieta
# Processing Record 20 of Set 11 | luderitz
# Processing Record 21 of Set 11 | richards bay
# Processing Record 22 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 11 | medicine hat
# Processing Record 24 of Set 11 | kaeo
# Processing Record 25 of Set 11 | okhotsk
# Processing Record 26 of Set 11 | asau
# Processing Record 27 of Set 11 | zory
# Processing Record 28 of Set 11 | nanortalik
# Processing Record 29 of Set 11 | college
# Processing Record 30 of Set 11 | pangnirtung
# Processing Record 31 of Set 11 | yusva
# City not found. Skipping...
# Processing Record 32 of Set 11 | port blair
# Processing Record 33 of Set 11 | buala
# Processing Record 34 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 11 | mill valley
# Processing Record 36 of Set 11 | lagunas
# Processing Record 37 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 38 of Set 11 | sorong
# Processing Record 39 of Set 11 | san rafael
# Processing Record 40 of Set 11 | yamada
# Processing Record 41 of Set 11 | agnibilekrou
# Processing Record 42 of Set 11 | cockburn town
# Processing Record 43 of Set 11 | birjand
# Processing Record 44 of Set 11 | drochia
# Processing Record 45 of Set 11 | coahuayana
# Processing Record 46 of Set 11 | los alamos
# Processing Record 47 of Set 11 | bafra
# Processing Record 48 of Set 11 | tiznit
# Processing Record 49 of Set 11 | pervomayskiy
# Processing Record 50 of Set 11 | dingzhou
# Processing Record 1 of Set 12 | manicore
# Processing Record 2 of Set 12 | manaure
# Processing Record 3 of Set 12 | gladstone
# Processing Record 4 of Set 12 | sturgeon falls
# Processing Record 5 of Set 12 | kommunisticheskiy
# Processing Record 6 of Set 12 | tornio
# Processing Record 7 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 12 | bergen
# Processing Record 9 of Set 12 | sobolevo
# Processing Record 10 of Set 12 | murray bridge
# Processing Record 11 of Set 12 | chhapar
# Processing Record 12 of Set 12 | snyder
# Processing Record 13 of Set 12 | msanga
# Processing Record 14 of Set 12 | ranong
# Processing Record 15 of Set 12 | kalianget
# Processing Record 16 of Set 12 | sosnovo-ozerskoye
# Processing Record 17 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 18 of Set 12 | ariquemes
# Processing Record 19 of Set 12 | monroe
# Processing Record 20 of Set 12 | khao yoi
# Processing Record 21 of Set 12 | yurla
# Processing Record 22 of Set 12 | walvis bay
# Processing Record 23 of Set 12 | amapala
# Processing Record 24 of Set 12 | asosa
# Processing Record 25 of Set 12 | anloga
# Processing Record 26 of Set 12 | deputatskiy
# Processing Record 27 of Set 12 | roebourne
# Processing Record 28 of Set 12 | honningsvag
# Processing Record 29 of Set 12 | meulaboh
# Processing Record 30 of Set 12 | lakes entrance
# Processing Record 31 of Set 12 | kapit
# Processing Record 32 of Set 12 | kasongo-lunda
# Processing Record 33 of Set 12 | mecca
# Processing Record 34 of Set 12 | vrangel
# Processing Record 35 of Set 12 | amahai
# Processing Record 36 of Set 12 | port hardy
# Processing Record 37 of Set 12 | phan thiet
# Processing Record 38 of Set 12 | russell
# Processing Record 39 of Set 12 | okha
# Processing Record 40 of Set 12 | aguia branca
# Processing Record 41 of Set 12 | usinsk
# Processing Record 42 of Set 12 | liverpool
# Processing Record 43 of Set 12 | harper
# Processing Record 44 of Set 12 | nemuro
# Processing Record 45 of Set 12 | opuwo
# Processing Record 46 of Set 12 | yatou
# Processing Record 47 of Set 12 | kosh-agach
# Processing Record 48 of Set 12 | ushibuka
# Processing Record 49 of Set 12 | wahiawa
# Processing Record 50 of Set 12 | tucumcari
# Processing Record 1 of Set 13 | ginir
# Processing Record 2 of Set 13 | vila franca do campo
# Processing Record 3 of Set 13 | zyryanovsk
# Processing Record 4 of Set 13 | porto walter
# Processing Record 5 of Set 13 | beyneu
# Processing Record 6 of Set 13 | mana
# Processing Record 7 of Set 13 | west wendover
# Processing Record 8 of Set 13 | turukhansk
# Processing Record 9 of Set 13 | champerico
# Processing Record 10 of Set 13 | mayumba
# Processing Record 11 of Set 13 | bebedouro
# Processing Record 12 of Set 13 | bam
# Processing Record 13 of Set 13 | qabis
# City not found. Skipping...
# Processing Record 14 of Set 13 | fukue
# Processing Record 15 of Set 13 | campbell river
# Processing Record 16 of Set 13 | los llanos de aridane
# Processing Record 17 of Set 13 | krasnoye
# Processing Record 18 of Set 13 | ballinasloe
# Processing Record 19 of Set 13 | fernie
# Processing Record 20 of Set 13 | gewane
# Processing Record 21 of Set 13 | ulaanbaatar
# Processing Record 22 of Set 13 | sao filipe
# Processing Record 23 of Set 13 | solnechnyy
# Processing Record 24 of Set 13 | northam
# Processing Record 25 of Set 13 | antofagasta
# Processing Record 26 of Set 13 | chaves
# Processing Record 27 of Set 13 | vieques
# Processing Record 28 of Set 13 | varkaus
# Processing Record 29 of Set 13 | dogondoutchi
# Processing Record 30 of Set 13 | pisco
# Processing Record 31 of Set 13 | borama
# City not found. Skipping...
# Processing Record 32 of Set 13 | barao de melgaco
# Processing Record 33 of Set 13 | bull savanna
# Processing Record 34 of Set 13 | porto santo
# Processing Record 35 of Set 13 | tulun
# Processing Record 36 of Set 13 | ye
# City not found. Skipping...
# Processing Record 37 of Set 13 | leh
# Processing Record 38 of Set 13 | kruisfontein
# Processing Record 39 of Set 13 | podgornoye
# Processing Record 40 of Set 13 | khomutovka
# Processing Record 41 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 13 | amga
# Processing Record 43 of Set 13 | churachandpur
# Processing Record 44 of Set 13 | kondinskoye
# Processing Record 45 of Set 13 | tonekabon
# Processing Record 46 of Set 13 | huilong
# Processing Record 47 of Set 13 | novaya mayna
# Processing Record 48 of Set 13 | the pas
# Processing Record 49 of Set 13 | yueyang
# Processing Record 50 of Set 13 | marawi
# Processing Record 1 of Set 14 | sambava
# Processing Record 2 of Set 14 | ewa beach
# Processing Record 3 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 14 | morondava
# Processing Record 5 of Set 14 | bilma
# Processing Record 6 of Set 14 | machaneng
# Processing Record 7 of Set 14 | nioro
# Processing Record 8 of Set 14 | peterhead
# Processing Record 9 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 14 | milove
# Processing Record 11 of Set 14 | yambio
# Processing Record 12 of Set 14 | gizo
# Processing Record 13 of Set 14 | young
# Processing Record 14 of Set 14 | kuusamo
# Processing Record 15 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 14 | evensk
# Processing Record 17 of Set 14 | rio gallegos
# Processing Record 18 of Set 14 | doha
# Processing Record 19 of Set 14 | quang ngai
# Processing Record 20 of Set 14 | shimoda
# Processing Record 21 of Set 14 | sao joao dos patos
# Processing Record 22 of Set 14 | algeciras
# Processing Record 23 of Set 14 | rafraf
# Processing Record 24 of Set 14 | swan river
# Processing Record 25 of Set 14 | shaki
# Processing Record 26 of Set 14 | general salgado
# Processing Record 27 of Set 14 | bang saphan
# Processing Record 28 of Set 14 | la ciotat
# Processing Record 29 of Set 14 | yeppoon
# Processing Record 30 of Set 14 | portugalete
# Processing Record 31 of Set 14 | ayan
# Processing Record 32 of Set 14 | ornskoldsvik
# Processing Record 33 of Set 14 | isla mujeres
# Processing Record 34 of Set 14 | brokopondo
# Processing Record 35 of Set 14 | chimbote
# Processing Record 36 of Set 14 | half moon bay
# Processing Record 37 of Set 14 | roald
# Processing Record 38 of Set 14 | along
# Processing Record 39 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 14 | pahrump
# Processing Record 41 of Set 14 | fare
# Processing Record 42 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 14 | mahajanga
# Processing Record 44 of Set 14 | kamina
# Processing Record 45 of Set 14 | kargil
# Processing Record 46 of Set 14 | taksimo
# Processing Record 47 of Set 14 | sayyan
# Processing Record 48 of Set 14 | constantine
# Processing Record 49 of Set 14 | san ignacio
# Processing Record 50 of Set 14 | kozulka
# Processing Record 1 of Set 15 | verkhnyaya inta
# Processing Record 2 of Set 15 | novokruchininskiy
# Processing Record 3 of Set 15 | whitehorse
# Processing Record 4 of Set 15 | taltal
# Processing Record 5 of Set 15 | basse-pointe
# Processing Record 6 of Set 15 | batagay
# Processing Record 7 of Set 15 | tahoua
# Processing Record 8 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 15 | bereda
# Processing Record 10 of Set 15 | pingliang
# Processing Record 11 of Set 15 | qobustan
# Processing Record 12 of Set 15 | chapeco
# Processing Record 13 of Set 15 | sadovoye
# Processing Record 14 of Set 15 | azul
# Processing Record 15 of Set 15 | san francisco
# Processing Record 16 of Set 15 | umkomaas
# Processing Record 17 of Set 15 | mount gambier
# Processing Record 18 of Set 15 | fallon
# Processing Record 19 of Set 15 | north bend
# Processing Record 20 of Set 15 | kuruman
# Processing Record 21 of Set 15 | hanmer springs
# Processing Record 22 of Set 15 | santa rosa
# Processing Record 23 of Set 15 | tamandare
# Processing Record 24 of Set 15 | abancay
# Processing Record 25 of Set 15 | clyde river
# Processing Record 26 of Set 15 | benidorm
# Processing Record 27 of Set 15 | tongliao
# Processing Record 28 of Set 15 | tunceli
# Processing Record 29 of Set 15 | mahanoro
# Processing Record 30 of Set 15 | chifeng
# Processing Record 31 of Set 15 | sompeta
# Processing Record 32 of Set 15 | dwarka
# Processing Record 33 of Set 15 | mildura
# Processing Record 34 of Set 15 | altay
# Processing Record 35 of Set 15 | vanavara
# Processing Record 36 of Set 15 | abu kamal
# Processing Record 37 of Set 15 | fayaoue
# Processing Record 38 of Set 15 | kawardha
# Processing Record 39 of Set 15 | esperance
# Processing Record 40 of Set 15 | ugoofaaru
# Processing Record 41 of Set 15 | fresno
# Processing Record 42 of Set 15 | twentynine palms
# Processing Record 43 of Set 15 | shingu
# Processing Record 44 of Set 15 | itapaci
# Processing Record 45 of Set 15 | sarny
# Processing Record 46 of Set 15 | jahrom
# City not found. Skipping...
# Processing Record 47 of Set 15 | burnie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Skoppum      NO  2021-03-07 23:46:06  59.3833   10.4167     32.00
# 1  Guerrero Negro      MX  2021-03-07 23:46:06  27.9769 -114.0611     62.40
# 2           Gaoua      BF  2021-03-07 23:46:07  10.2992   -3.2508     83.07
# 3          Vostok      RU  2021-03-07 23:46:07  46.4856  135.8833     12.02
# 4           Pevek      RU  2021-03-07 23:46:08  69.7008  170.3133    -16.06
# 5        Benguela      AO  2021-03-07 23:46:09 -12.5763   13.4055     80.58
# 6       Upernavik      GL  2021-03-07 23:46:09  72.7868  -56.1549    -18.74
# 7         Mataura      NZ  2021-03-07 23:46:09 -46.1927  168.8643     55.00
# 8       Chapaevsk      RU  2021-03-07 23:46:10  52.9813   49.7112     23.00
# 9           Vardo      NO  2021-03-07 23:46:10  70.3705   31.1107     15.80
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        40          18        3.44          few clouds
# 1        60          18       16.53          few clouds
# 2        50          91        4.59     overcast clouds
# 3        95         100        4.97     overcast clouds
# 4        88         100       21.99          light snow
# 5        76         100        5.73     overcast clouds
# 6        81           0       13.00           clear sky
# 7        74          97       11.01     overcast clouds
# 8        93          75       17.90                snow
# 9        86          20       11.50          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
